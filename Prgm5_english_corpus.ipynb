# %%
text=open("D:/EngCorpus.txt").read()
print("tokenization of the sentences in the data:")
text.split(". ")
# Out:
# tokenization of the sentences in the data:
# ['Hyderabad is the capital and largest city of the Indian state of Telangana and the\nde jure capital of Andhra Pradesh',
#  'Occupying 625 square kilometres\n(241 sq mi) along the banks of the Musi River, it is located on the\nDeccan Plateau in the northern part of South India',
#  "With an average\naltitude of 542 metres (1,778 ft), much of Hyderabad is situated on\nhilly terrain around artificial lakes, including the Hussain Sagar\nlake, predating the city's founding, in the north of the city centre.\nAccording to the 2011 Census of India, Hyderabad is the fourth-most\npopulous city in India with a population of 6.9 million residents\nwithin the city limits, and has a population of 9.7 million residents\nin the metropolitan region, making it the sixth-most populous\nmetropolitan area in India",
#  'With an output of US$74 billion, Hyderabad\nhas the fifth-largest urban economy in India.\n\nMuhammad Quli Qutb Shah established Hyderabad in 1591 to extend the\ncapital beyond the fortified Golconda',
#  'In 1687, the city was annexed\nby the Mughals',
#  'In 1724, Mughal governor Nizam Asaf Jah I declared his\nsovereignty and founded the Asaf Jahi dynasty, also known as the\nNizams',
#  'Hyderabad served as the imperial capital of the Asaf Jahis\nfrom 1769 to 1948',
#  'As capital of the princely state of Hyderabad, the\ncity housed the British Residency and cantonment until Indian\nindependence in 1947',
#  'Hyderabad was integrated into the Indian Union\nin 1948 and continued as a capital of Hyderabad State (1948â€“56)',
#  'After\nthe introduction of the States Reorganisation Act of 1956, Hyderabad\nwas made the capital of the newly-formed Andhra Pradesh',
#  'In 2014,\nAndhra Pradesh was bifurcated to form Telangana and Hyderabad became\nthe joint capital of the two states with a transitional arrangement\nscheduled to end in 2024',
#  'Since 1956, the city has housed the winter\noffice of the President of India.\n\nRelics of the Qutb Shahi and Nizam rules remain visible today; the\nCharminar has come to symbolise the city',
#  "By the end of early modern\nera, the Mughal Empire declined in the Deccan and the Nizams'\npatronage had attracted men of letters from different parts of the\nworld",
#  'The amalgamation of local and migrated artisans had originated\na distinctive culture, and the city emerged as the foremost centre of\noriental culture',
#  'Painting, handicraft, jewellery, literature, dialect\nand clothing are prominent still today',
#  'Through its cuisine, the city\nis listed as a UNESCO creative city of gastronomy',
#  'The Telugu film\nindustry based in the city is the country\'s second-largest producer of\nmotion pictures.\n\nUntil the 19th century Hyderabad was known for the pearl industry and\nwas nicknamed the "City of Pearls", and was the only Golconda Diamonds\ntrading centre in the world',
#  "Many of the city's historical and\ntraditional bazaars remain open",
#  "Hyderabad's central location between\nthe Deccan Plateau and the Western Ghats, and industrialisation\nthroughout the 20th century attracted major Indian research,\nmanufacturing, educational and financial institutions",
#  'Since the\n1990s, the city has emerged as an Indian hub of pharmaceuticals and\nbiotechnology',
#  'The formation of special economic zones and HITEC City\ndedicated to information technology has encouraged leading\nmultinationals to set up operations in Hyderabad.']

# %%
print("tokenization of the words in the data:")
text.split()
# Out:
# tokenization of the words in the data:
# ['Hyderabad',
#  'is',
#  'the',
#  'capital',
#  'and',
#  'largest',
#  'city',
#  'of',
#  'the',
#  'Indian',
#  'state',
#  'of',
#  'Telangana',
#  'and',
#  'the',
#  'de',
#  'jure',
#  'capital',
#  'of',
#  'Andhra',
#  'Pradesh.',
#  'Occupying',
#  '625',
#  'square',
#  'kilometres',
#  '(241',
#  'sq',
#  'mi)',
#  'along',
#  'the',
#  'banks',
#  'of',
#  'the',
#  'Musi',
#  'River,',
#  'it',
#  'is',
#  'located',
#  'on',
#  'the',
#  'Deccan',
#  'Plateau',
#  'in',
#  'the',
#  'northern',
#  'part',
#  'of',
#  'South',
#  'India.',
#  'With',
#  'an',
#  'average',
#  'altitude',
#  'of',
#  '542',
#  'metres',
#  '(1,778',
#  'ft),',
#  'much',
#  'of',
#  'Hyderabad',
#  'is',
#  'situated',
#  'on',
#  'hilly',
#  'terrain',
#  'around',
#  'artificial',
#  'lakes,',
#  'including',
#  'the',
#  'Hussain',
#  'Sagar',
#  'lake,',
#  'predating',
#  'the',
#  "city's",
#  'founding,',
#  'in',
#  'the',
#  'north',
#  'of',
#  'the',
#  'city',
#  'centre.',
#  'According',
#  'to',
#  'the',
#  '2011',
#  'Census',
#  'of',
#  'India,',
#  'Hyderabad',
#  'is',
#  'the',
#  'fourth-most',
#  'populous',
#  'city',
#  'in',
#  'India',
#  'with',
#  'a',
#  'population',
#  'of',
#  '6.9',
#  'million',
#  'residents',
#  'within',
#  'the',
#  'city',
#  'limits,',
#  'and',
#  'has',
#  'a',
#  'population',
#  'of',
#  '9.7',
#  'million',
#  'residents',
#  'in',
#  'the',
#  'metropolitan',
#  'region,',
#  'making',
#  'it',
#  'the',
#  'sixth-most',
#  'populous',
#  'metropolitan',
#  'area',
#  'in',
#  'India.',
#  'With',
#  'an',
#  'output',
#  'of',
#  'US$74',
#  'billion,',
#  'Hyderabad',
#  'has',
#  'the',
#  'fifth-largest',
#  'urban',
#  'economy',
#  'in',
#  'India.',
#  'Muhammad',
#  'Quli',
#  'Qutb',
#  'Shah',
#  'established',
#  'Hyderabad',
#  'in',
#  '1591',
#  'to',
#  'extend',
#  'the',
#  'capital',
#  'beyond',
#  'the',
#  'fortified',
#  'Golconda.',
#  'In',
#  '1687,',
#  'the',
#  'city',
#  'was',
#  'annexed',
#  'by',
#  'the',
#  'Mughals.',
#  'In',
#  '1724,',
#  'Mughal',
#  'governor',
#  'Nizam',
#  'Asaf',
#  'Jah',
#  'I',
#  'declared',
#  'his',
#  'sovereignty',
#  'and',
#  'founded',
#  'the',
#  'Asaf',
#  'Jahi',
#  'dynasty,',
#  'also',
#  'known',
#  'as',
#  'the',
#  'Nizams.',
#  'Hyderabad',
#  'served',
#  'as',
#  'the',
#  'imperial',
#  'capital',
#  'of',
#  'the',
#  'Asaf',
#  'Jahis',
#  'from',
#  '1769',
#  'to',
#  '1948.',
#  'As',
#  'capital',
#  'of',
#  'the',
#  'princely',
#  'state',
#  'of',
#  'Hyderabad,',
#  'the',
#  'city',
#  'housed',
#  'the',
#  'British',
#  'Residency',
#  'and',
#  'cantonment',
#  'until',
#  'Indian',
#  'independence',
#  'in',
#  '1947.',
#  'Hyderabad',
#  'was',
#  'integrated',
#  'into',
#  'the',
#  'Indian',
#  'Union',
#  'in',
#  '1948',
#  'and',
#  'continued',
#  'as',
#  'a',
#  'capital',
#  'of',
#  'Hyderabad',
#  'State',
#  '(1948â€“56).',
#  'After',
#  'the',
#  'introduction',
#  'of',
#  'the',
#  'States',
#  'Reorganisation',
#  'Act',
#  'of',
#  '1956,',
#  'Hyderabad',
#  'was',
#  'made',
#  'the',
#  'capital',
#  'of',
#  'the',
#  'newly-formed',
#  'Andhra',
#  'Pradesh.',
#  'In',
#  '2014,',
#  'Andhra',
#  'Pradesh',
#  'was',
#  'bifurcated',
#  'to',
#  'form',
#  'Telangana',
#  'and',
#  'Hyderabad',
#  'became',
#  'the',
#  'joint',
#  'capital',
#  'of',
#  'the',
#  'two',
#  'states',
#  'with',
#  'a',
#  'transitional',
#  'arrangement',
#  'scheduled',
#  'to',
#  'end',
#  'in',
#  '2024.',
#  'Since',
#  '1956,',
#  'the',
#  'city',
#  'has',
#  'housed',
#  'the',
#  'winter',
#  'office',
#  'of',
#  'the',
#  'President',
#  'of',
#  'India.',
#  'Relics',
#  'of',
#  'the',
#  'Qutb',
#  'Shahi',
#  'and',
#  'Nizam',
#  'rules',
#  'remain',
#  'visible',
#  'today;',
#  'the',
#  'Charminar',
#  'has',
#  'come',
#  'to',
#  'symbolise',
#  'the',
#  'city.',
#  'By',
#  'the',
#  'end',
#  'of',
#  'early',
#  'modern',
#  'era,',
#  'the',
#  'Mughal',
#  'Empire',
#  'declined',
#  'in',
#  'the',
#  'Deccan',
#  'and',
#  'the',
#  "Nizams'",
#  'patronage',
#  'had',
#  'attracted',
#  'men',
#  'of',
#  'letters',
#  'from',
#  'different',
#  'parts',
#  'of',
#  'the',
#  'world.',
#  'The',
#  'amalgamation',
#  'of',
#  'local',
#  'and',
#  'migrated',
#  'artisans',
#  'had',
#  'originated',
#  'a',
#  'distinctive',
#  'culture,',
#  'and',
#  'the',
#  'city',
#  'emerged',
#  'as',
#  'the',
#  'foremost',
#  'centre',
#  'of',
#  'oriental',
#  'culture.',
#  'Painting,',
#  'handicraft,',
#  'jewellery,',
#  'literature,',
#  'dialect',
#  'and',
#  'clothing',
#  'are',
#  'prominent',
#  'still',
#  'today.',
#  'Through',
#  'its',
#  'cuisine,',
#  'the',
#  'city',
#  'is',
#  'listed',
#  'as',
#  'a',
#  'UNESCO',
#  'creative',
#  'city',
#  'of',
#  'gastronomy.',
#  'The',
#  'Telugu',
#  'film',
#  'industry',
#  'based',
#  'in',
#  'the',
#  'city',
#  'is',
#  'the',
#  "country's",
#  'second-largest',
#  'producer',
#  'of',
#  'motion',
#  'pictures.',
#  'Until',
#  'the',
#  '19th',
#  'century',
#  'Hyderabad',
#  'was',
#  'known',
#  'for',
#  'the',
#  'pearl',
#  'industry',
#  'and',
#  'was',
#  'nicknamed',
#  'the',
#  '"City',
#  'of',
#  'Pearls",',
#  'and',
#  'was',
#  'the',
#  'only',
#  'Golconda',
#  'Diamonds',
#  'trading',
#  'centre',
#  'in',
#  'the',
#  'world.',
#  'Many',
#  'of',
#  'the',
#  "city's",
#  'historical',
#  'and',
#  'traditional',
#  'bazaars',
#  'remain',
#  'open.',
#  "Hyderabad's",
#  'central',
#  'location',
#  'between',
#  'the',
#  'Deccan',
#  'Plateau',
#  'and',
#  'the',
#  'Western',
#  'Ghats,',
#  'and',
#  'industrialisation',
#  'throughout',
#  'the',
#  '20th',
#  'century',
#  'attracted',
#  'major',
#  'Indian',
#  'research,',
#  'manufacturing,',
#  'educational',
#  'and',
#  'financial',
#  'institutions.',
#  'Since',
#  'the',
#  '1990s,',
#  'the',
#  'city',
#  'has',
#  'emerged',
#  'as',
#  'an',
#  'Indian',
#  'hub',
#  'of',
#  'pharmaceuticals',
#  'and',
#  'biotechnology.',
#  'The',
#  'formation',
#  'of',
#  'special',
#  'economic',
#  'zones',
#  'and',
#  'HITEC',
#  'City',
#  'dedicated',
#  'to',
#  'information',
#  'technology',
#  'has',
#  'encouraged',
#  'leading',
#  'multinationals',
#  'to',
#  'set',
#  'up',
#  'operations',
#  'in',
#  'Hyderabad.']

# %%
I = text.split()
word_frequancy = {} 
character_frequency = dict()

for w in I:
  if w not in word_frequancy.keys():
    word_frequancy[w] = 0 
  word_frequancy[w] = word_frequancy[w] +1
print("the frequancy of the words are ", word_frequancy)

for c in  text:
  if c in character_frequency :
    character_frequency [c] = character_frequency [c] +1
  else :
    character_frequency [c] =1

print ("the frequency of character are", character_frequency)
# Out:
# the frequancy of the words are  {'Hyderabad': 11, 'is': 6, 'the': 62, 'capital': 8, 'and': 20, 'largest': 1, 'city': 12, 'of': 34, 'Indian': 5, 'state': 2, 'Telangana': 2, 'de': 1, 'jure': 1, 'Andhra': 3, 'Pradesh.': 2, 'Occupying': 1, '625': 1, 'square': 1, 'kilometres': 1, '(241': 1, 'sq': 1, 'mi)': 1, 'along': 1, 'banks': 1, 'Musi': 1, 'River,': 1, 'it': 2, 'located': 1, 'on': 2, 'Deccan': 3, 'Plateau': 2, 'in': 14, 'northern': 1, 'part': 1, 'South': 1, 'India.': 4, 'With': 2, 'an': 3, 'average': 1, 'altitude': 1, '542': 1, 'metres': 1, '(1,778': 1, 'ft),': 1, 'much': 1, 'situated': 1, 'hilly': 1, 'terrain': 1, 'around': 1, 'artificial': 1, 'lakes,': 1, 'including': 1, 'Hussain': 1, 'Sagar': 1, 'lake,': 1, 'predating': 1, "city's": 2, 'founding,': 1, 'north': 1, 'centre.': 1, 'According': 1, 'to': 8, '2011': 1, 'Census': 1, 'India,': 1, 'fourth-most': 1, 'populous': 2, 'India': 1, 'with': 2, 'a': 6, 'population': 2, '6.9': 1, 'million': 2, 'residents': 2, 'within': 1, 'limits,': 1, 'has': 6, '9.7': 1, 'metropolitan': 2, 'region,': 1, 'making': 1, 'sixth-most': 1, 'area': 1, 'output': 1, 'US$74': 1, 'billion,': 1, 'fifth-largest': 1, 'urban': 1, 'economy': 1, 'Muhammad': 1, 'Quli': 1, 'Qutb': 2, 'Shah': 1, 'established': 1, '1591': 1, 'extend': 1, 'beyond': 1, 'fortified': 1, 'Golconda.': 1, 'In': 3, '1687,': 1, 'was': 7, 'annexed': 1, 'by': 1, 'Mughals.': 1, '1724,': 1, 'Mughal': 2, 'governor': 1, 'Nizam': 2, 'Asaf': 3, 'Jah': 1, 'I': 1, 'declared': 1, 'his': 1, 'sovereignty': 1, 'founded': 1, 'Jahi': 1, 'dynasty,': 1, 'also': 1, 'known': 2, 'as': 6, 'Nizams.': 1, 'served': 1, 'imperial': 1, 'Jahis': 1, 'from': 2, '1769': 1, '1948.': 1, 'As': 1, 'princely': 1, 'Hyderabad,': 1, 'housed': 2, 'British': 1, 'Residency': 1, 'cantonment': 1, 'until': 1, 'independence': 1, '1947.': 1, 'integrated': 1, 'into': 1, 'Union': 1, '1948': 1, 'continued': 1, 'State': 1, '(1948â€“56).': 1, 'After': 1, 'introduction': 1, 'States': 1, 'Reorganisation